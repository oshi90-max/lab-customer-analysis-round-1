# %%
import pandas as pd
import numpy as np

file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')


column_names1 = file1.columns
column_names2 = file2.columns
column_names3 = file3.columns

#display(column_names1)
#display(column_names2)
#display(column_names3)

file3 = file3.rename(columns={'State':'ST'})
display(column_names3)


data = pd.concat([file1, file2, file3], axis=0) 
data.shape
data
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California    NaN              Bachelor
# 7066  PK87824  California    NaN               College
# 7067  TD14365  California    NaN              Bachelor
# 7068  UP19263  California    NaN               College
# 7069  Y167826  California    NaN               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# ...

# %%
data._get_numeric_data()
# Out:
#        Income  Monthly Premium Auto  Total Claim Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
data.select_dtypes("object")
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California    NaN              Bachelor
# 7066  PK87824  California    NaN               College
# 7067  TD14365  California    NaN              Bachelor
# 7068  UP19263  California    NaN               College
# 7069  Y167826  California    NaN               College
#
#      Customer Lifetime Value Number of Open Complaints     Policy Type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
round(data.isna().sum()/len(data),4)*100  # shows the percentage of null values in a column
nulls_data = pd.DataFrame(round(data.isna().sum()/len(data),4)*100)
nulls_data
#data["Customer"].value_counts(dropna=False)
# Out:
#                                0
# Customer                   24.32
# ST                         24.32
# GENDER                     83.89
# Education                  24.32
# Customer Lifetime Value    24.38
# Income                     24.32
# Monthly Premium Auto       24.32
# Number of Open Complaints  24.32
# Policy Type                24.32
# Vehicle Class              24.32
# Total Claim Amount         24.32
# Gender                     41.44
